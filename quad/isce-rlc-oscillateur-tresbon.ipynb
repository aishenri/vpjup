# %% [markdown]
# ###### An de grâce 2017
# iCSE_FElekmag05_z10_Oscylator_elektryczny_LC_(nietlumiony)

# %%
# %display latex
t = var('t')
var('L, C, t0, q0, I0')
q = function('q')(t)
assume(L>0)
assume(C>0)
assume(t>0)
LC = L*diff(q,t,2)+q/C == 0;LC
# Out:
# L*diff(q(t), t, t) + q(t)/C == 0

# %%
q_LCo = desolve(LC, q, ivar=t);q_LCo
# Out:
# _K2*cos(t/(sqrt(C)*sqrt(L))) + _K1*sin(t/(sqrt(C)*sqrt(L)))

# %%
q_LC = desolve(LC, q, ivar=t, ics=[t0,q0,I0]);q_LC
# Out:
# -(sqrt(C)*I0*sqrt(L)*sin(t0/(sqrt(C)*sqrt(L))) - q0*cos(t0/(sqrt(C)*sqrt(L))))*cos(t/(sqrt(C)*sqrt(L)))/(cos(t0/(sqrt(C)*sqrt(L)))^2 + sin(t0/(sqrt(C)*sqrt(L)))^2) + (sqrt(C)*I0*sqrt(L)*cos(t0/(sqrt(C)*sqrt(L))) + q0*sin(t0/(sqrt(C)*sqrt(L))))*sin(t/(sqrt(C)*sqrt(L)))/(cos(t0/(sqrt(C)*sqrt(L)))^2 + sin(t0/(sqrt(C)*sqrt(L)))^2)

# %%
I=diff(q_LC, t, 1);I
# Out:
# (sqrt(C)*I0*sqrt(L)*cos(t0/(sqrt(C)*sqrt(L))) + q0*sin(t0/(sqrt(C)*sqrt(L))))*cos(t/(sqrt(C)*sqrt(L)))/((cos(t0/(sqrt(C)*sqrt(L)))^2 + sin(t0/(sqrt(C)*sqrt(L)))^2)*sqrt(C)*sqrt(L)) + (sqrt(C)*I0*sqrt(L)*sin(t0/(sqrt(C)*sqrt(L))) - q0*cos(t0/(sqrt(C)*sqrt(L))))*sin(t/(sqrt(C)*sqrt(L)))/((cos(t0/(sqrt(C)*sqrt(L)))^2 + sin(t0/(sqrt(C)*sqrt(L)))^2)*sqrt(C)*sqrt(L))

# %%
plotq_LC=q_LC.substitute(t0=0, q0=1, I0=0, L=12e-2, C=1.5e-4);

# %%
p_c=plot(plotq_LC, (0, 0.05),color="red")

# %%
plot_I=I.substitute(t0=0, q0=0.01, I0=0, L=12e-1, C=1.5e-5);

# %%
p_i=plot(plot_I, (0, 0.05), color='blue')
show(p_c+p_i)
# Out:
# Graphics object consisting of 2 graphics primitives
