# %%
import nglview;import nglview as nv
view = nv.show_pdbid("ADE")
view.add_licorice("gly");view.remove_label()
view.add_label("gly",color="green",label_type="atomname");view
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipykernel_7941/844792463.py in <module>
#       1 import nglview;import nglview as nv
# ----> 2 view = nv.show_pdbid("ADE")
#       3 view.add_licorice("gly");view.remove_label()
#       4 view.add_label("gly",color="green",label_type="atomname");view
#
# /usr/local/lib/python3.10/dist-packages/nglview/show.py in show_pdbid(pdbid, **kwargs)
#      52     '''
#      53     structure = PdbIdStructure(pdbid)
# ---> 54     return NGLWidget(structure, **kwargs)
#      55
#      56
#
# /usr/local/lib/python3.10/dist-packages/nglview/widget.py in __init__(self, structure, representations, parameters, **kwargs)
#     243         else:
#     244             if structure is not None:
# --> 245                 self.add_structure(structure, **kwargs)
#     246
#     247         if representations:
#
# ...

# %%
import biotite.structure as struc
import biotite.structure.info as info
import ammolite;PNG_SIZE = (300, 300)
ala = info.residue("ade");print(ala)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7941/1436862374.py in <module>
#       2 import biotite.structure.info as info
#       3 import ammolite;PNG_SIZE = (Integer(300), Integer(300))
# ----> 4 ala = info.residue("ade");print(ala)
#
# /usr/local/lib/python3.10/dist-packages/biotite/structure/info/atoms.py in residue(res_name)
#      92     """
#      93     _init_dataset()
# ---> 94     array_dict = _residues[res_name]
#      95
#      96     array = AtomArray(len(array_dict["res_name"]))
#
# KeyError: 'ade'

# %%
import nglview;view=nglview.show_file("ALA.cif")
view.add_licorice("ala");view.remove_label()
view.add_label("ALA",color="green",label_type="atomname");view
# Out:
# NGLWidget()

# %%
ala = info.residue("ALA");print(ala)
# Out:
#             0  ALA N      N        -0.966    0.493    1.500
#             0  ALA CA     C         0.257    0.418    0.692
#             0  ALA C      C        -0.094    0.017   -0.716
#             0  ALA O      O        -1.056   -0.682   -0.923
#             0  ALA CB     C         1.204   -0.620    1.296
#             0  ALA OXT    O         0.661    0.439   -1.742
#             0  ALA H      H        -1.383   -0.425    1.482
#             0  ALA H2     H        -0.676    0.661    2.452
#             0  ALA HA     H         0.746    1.392    0.682
#             0  ALA HB1    H         1.459   -0.330    2.316
#             0  ALA HB2    H         0.715   -1.594    1.307
#             0  ALA HB3    H         2.113   -0.676    0.697
#             0  ALA HXT    H         0.435    0.182   -2.647
