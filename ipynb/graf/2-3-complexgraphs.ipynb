# %%
def complex_point_plot(pts): 
    return list_plot([(real(i), imag(i)) for i in pts], 
                     axes_labels = ['Re($z$)', 'Im($z$)'], size=10) 
pts = [e^(i*(theta)) for theta in srange(0, 2*pi, .1)] 
show(complex_point_plot(pts),aspect_ratio=1,figsize=4,frame=True)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
def complex_point_plot(pts): 
    """ 
    A function that returns a plot of a list of complex points. 
    Arguments: pts (a list of complex numbers) 
    Outputs: A list plot of the imaginary numbers 
    """ 
    return list_plot([(real(i), 
                       imag(i)) for i in pts], 
                     axes_labels = ['Re($z$)', 'Im($z$)'], size=50) 
show(complex_point_plot([3*i, e^(I*pi), 
                         e^(i*3*pi/4),-4,4-4*i]),frame=True,figsize=4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
show(complex_point_plot([e^(i*pi),-1]),frame=True,figsize=4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
pts = [e^(i*(theta)) for theta in srange(0, pi, .1)] 
show(complex_point_plot(pts),aspect_ratio=1,figsize=4,frame=True)
# Out:
# Graphics object consisting of 1 graphics primitive
