# %%
# %display latex

# %% [markdown]
# ###### Vecteur $\mu$ et $\epsilon$
#
# $\nabla .E=\frac {\mu}{\epsilon}$ = $\frac {L}{C} = Z$

# %%
E.<x,y> = EuclideanSpace()
f = E.vector_field(x, y, name='f')
(f.divergence()).display()
# Out:
# div(f): E^2 --> R
#    (x, y) |--> 2

# %%
from sage.manifolds.operators import *
div(f).display()
# Out:
# div(f): E^2 --> R
#    (x, y) |--> 2

# %%
c=circle((0,0),10)
c+(-f).plot(xmin=-10,xmax=10,ymin=-10,ymax=10,figsize=5)
# Out:
# Graphics object consisting of 81 graphics primitives

# %%
sqrt((4*n(pi))/(n(pi)*4E-7))
# Out:
# 3162.27766016838

# %%
sqrt(10.0)
# Out:
# 3.16227766016838

# %%
a=201360;a*sqrt(2.0)
# Out:
# 284766.042919446

# %%
c=circle((0,0),15)
c+(f).plot(xmin=-15,xmax=15,ymin=-15,ymax=15,figsize=5)
# Out:
# Graphics object consisting of 81 graphics primitives
