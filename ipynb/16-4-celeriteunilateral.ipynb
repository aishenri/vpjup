# %% [markdown]
# En décomposant l'équation de la lumière : c=racine carré de l'inverse du produit de $\mu$*$\epsilon$, je me suis rendu compte  qu'on obtenait un niveau cellule.

# %%
p= polygon(((0.0,0.0),(0,2),(2,2),(2,0)), color="cyan",
             edgecolor="red", thickness=2)
r=2/sqrt(n(pi))
c=circle((1,1),r)
show(p+c, 
     xmin=-0.1,xmax=2.1,ymin=-0.1,ymax=2.1,gridlines="minor",
     gridlinesstyle=dict(color="green",
                         linestyle="-"),axes=True,frame=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
p= polygon(((-0.5,-0.5),(-0.5,0.5),(0.5,0.5),(0.5,-0.5)), 
color="cyan",edgecolor="red", thickness=2)
r=2/sqrt(n(pi))
c=circle((0,0),r/2)
s=circle((0,0),r/8,color="red")
show(p+c+s,
xmin=-0.6,xmax=0.6,ymin=-0.6,ymax=0.6,gridlines="minor",
gridlinesstyle=dict(color="green",linestyle="-"),
figsize=10,axes=True,frame=True)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
a=r/2;b=r/8;1/(a/77.3138)
# Out:
# 137.035142538139

# %%
a/77.3138
# Out:
# 0.00729739818179622

# %% [markdown]
# Il existe dans l'univers une loi de quadrature, c'est-à-dire un rapport de force entre le carré et le cercle, quand ils sont en quadrature, ils sont en résonnance. Je peux que c'est la génèse (origine) de la force !
# Très proche de la constante $\alpha$, sans doute aussi l'origine de celle-ci ?

# %%
1/137.03599971096
# Out:
# 0.00729735253589733

# %%
a/b
# Out:
# 4.00000000000000

# %%
u=1/n(pi)*360E-8;u
# Out:
# 1.14591559026165e-6

# %%
s=1/(n(pi*360E+8));s
# Out:
# 8.84194128288307e-12

# %%
z=u/s;round(z)
# Out:
# 129600

# %% [markdown]
# $\pi$ est un mirage algèbrique, il permet de montrer les déficiences de la physique. Voir julia notebook : 16-4-mu.par.epsilon

# %%
c=299792458;mu=n(pi)*4E-7;eps=1/(mu*c*c);mu,eps
# Out:
# (1.25663706143592e-6, 8.85418781762039e-12)

# %%
u,s
# Out:
# (1.14591559026165e-6, 8.84194128288307e-12)

# %%
(mu/u),(eps/s)
# Out:
# (1.09662271123215, 1.00138505044826)

# %%
1/u*1/s
# Out:
# 9.86960440108936e16
